# %% [markdown]
# # QC

# %%
# %%bash
#
# #PAIRED READS QC
#
# mkdir 3_qc
# mkdir 4_merged_fastq
# mkdir 5_merged_fasta
#
# libraries=$(ls -1 2_demultiplexed)
# for library in $libraries
# do
#     mkdir 3_qc/${library}/
#     mkdir 4_merged_fastq/${library}/
#     mkdir 5_merged_fasta/${library}/
#     files=$(ls -1 2_demultiplexed/${library} | grep -v invalid | grep R1.fastq | sed 's/.R1.fastq.*//')
#     for sample in $files
#     do
#         fastp -i 2_demultiplexed/${library}/${sample}.R1.fastq -I 2_demultiplexed/${library}/${sample}.R2.fastq \
#         -o 3_qc/${library}/${sample}.R1.fastq -O 3_qc/${library}/${sample}.R2.fastq \
#         --unpaired1 3_qc/${library}/${sample}_unpaired.R1.fastq \
#         --unpaired2 3_qc/${library}/${sample}_unpaired.R2.fastq \
#         --failed_out 3_qc/${library}/${sample}_failed.fastq \
#         -q 30 \
#         --cut_tail \
#         --trim_front1 20 \
#         --trim_front2 20 \
#         --max_len1 106 \
#         --max_len2 106 \
#         -l 90 \
#         --merge \
#         --overlap_len_require 90 \
#         --correction \
#         --merged_out 4_merged_fastq/${library}/${sample}_merged.fastq \
#         -w 6 \
#         -h ./fastp_out/${sample}_fastp.html \
#         -j ./fastp_out/${sample}_fastp.json
#         cat 3_qc/${library}/${sample}.R1.fastq >> 4_merged_fastq/${library}/${sample}_merged.fastq
#         cat 3_qc/${library}/${sample}_unpaired.R1.fastq >> 4_merged_fastq/${library}/${sample}_merged.fastq
#         seqkit fq2fa 4_merged_fastq/${library}/${sample}_merged.fastq -o 5_merged_fasta/${library}/${sample}_merged.fasta
#     done
# done
# Out:
# Read1 before filtering:
# total reads: 81
# total bases: 6081
# Q20 bases: 5138(84.4927%)
# Q30 bases: 4471(73.5241%)
#
# Read2 before filtering:
# total reads: 81
# total bases: 5326
# Q20 bases: 4805(90.2178%)
# Q30 bases: 4392(82.4634%)
#
# Merged and filtered:
# total reads: 5
# total bases: 510
# Q20 bases: 488(95.6863%)
# Q30 bases: 461(90.3922%)
#
# Filtering result:
# reads passed filter: 10
# reads failed due to low quality: 28
# reads failed due to too many N: 0
# reads failed due to too short: 124
# reads with adapter trimmed: 10
# bases trimmed due to adapters: 111
# reads corrected by overlap analysis: 3
# bases corrected by overlap analysis: 3
#
# Duplication rate: 0%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 5
# % of original read pairs: 6.17284%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/21AU_fastp.json
# HTML report: ./fastp_out/21AU_fastp.html
#
# fastp -i 2_demultiplexed/ADD/21AU.R1.fastq -I 2_demultiplexed/ADD/21AU.R2.fastq -o 3_qc/ADD/21AU.R1.fastq -O 3_qc/ADD/21AU.R2.fastq --unpaired1 3_qc/ADD/21AU_unpaired.R1.fastq --unpaired2 3_qc/ADD/21AU_unpaired.R2.fastq --failed_out 3_qc/ADD/21AU_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/21AU_merged.fastq -w 6 -h ./fastp_out/21AU_fastp.html -j ./fastp_out/21AU_fastp.json
# fastp v0.20.0, time used: 0 seconds
# Read1 before filtering:
# total reads: 1535
# total bases: 90946
# Q20 bases: 85410(93.9129%)
# Q30 bases: 79450(87.3595%)
#
# Read2 before filtering:
# total reads: 1535
# total bases: 87335
# Q20 bases: 84386(96.6233%)
# Q30 bases: 80974(92.7166%)
#
# Merged and filtered:
# total reads: 1
# total bases: 104
# Q20 bases: 96(92.3077%)
# Q30 bases: 87(83.6538%)
#
# Filtering result:
# reads passed filter: 2
# reads failed due to low quality: 274
# reads failed due to too many N: 0
# reads failed due to too short: 2794
# reads with adapter trimmed: 2
# bases trimmed due to adapters: 20
# reads corrected by overlap analysis: 1
# bases corrected by overlap analysis: 1
#
# Duplication rate: 0%
#
# Insert size peak (evaluated by paired-end reads): 144
#
# Read pairs merged: 1
# % of original read pairs: 0.0651466%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/21SM_fastp.json
# HTML report: ./fastp_out/21SM_fastp.html
#
# fastp -i 2_demultiplexed/ADD/21SM.R1.fastq -I 2_demultiplexed/ADD/21SM.R2.fastq -o 3_qc/ADD/21SM.R1.fastq -O 3_qc/ADD/21SM.R2.fastq --unpaired1 3_qc/ADD/21SM_unpaired.R1.fastq --unpaired2 3_qc/ADD/21SM_unpaired.R2.fastq --failed_out 3_qc/ADD/21SM_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/21SM_merged.fastq -w 6 -h ./fastp_out/21SM_fastp.html -j ./fastp_out/21SM_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 39825
# total bases: 3652193
# Q20 bases: 3507078(96.0266%)
# Q30 bases: 3313609(90.7293%)
#
# Read2 before filtering:
# total reads: 39825
# total bases: 3581878
# Q20 bases: 3469358(96.8586%)
# Q30 bases: 3301891(92.1832%)
#
# Merged and filtered:
# total reads: 12476
# total bases: 1284969
# Q20 bases: 1268950(98.7534%)
# Q30 bases: 1224682(95.3083%)
#
# Filtering result:
# reads passed filter: 25118
# reads failed due to low quality: 5984
# reads failed due to too many N: 0
# reads failed due to too short: 48548
# reads with adapter trimmed: 25310
# bases trimmed due to adapters: 317442
# reads corrected by overlap analysis: 2579
# bases corrected by overlap analysis: 4466
#
# Duplication rate: 27.2727%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 12476
# % of original read pairs: 31.3271%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A47S_fastp.json
# HTML report: ./fastp_out/A47S_fastp.html
#
# fastp -i 2_demultiplexed/ADD/A47S.R1.fastq -I 2_demultiplexed/ADD/A47S.R2.fastq -o 3_qc/ADD/A47S.R1.fastq -O 3_qc/ADD/A47S.R2.fastq --unpaired1 3_qc/ADD/A47S_unpaired.R1.fastq --unpaired2 3_qc/ADD/A47S_unpaired.R2.fastq --failed_out 3_qc/ADD/A47S_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/A47S_merged.fastq -w 6 -h ./fastp_out/A47S_fastp.html -j ./fastp_out/A47S_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 98932
# total bases: 15126507
# Q20 bases: 14832479(98.0562%)
# Q30 bases: 14265399(94.3073%)
#
# Read2 before filtering:
# total reads: 98932
# total bases: 15112446
# Q20 bases: 14762368(97.6835%)
# Q30 bases: 14110991(93.3733%)
#
# Merged and filtered:
# total reads: 94669
# total bases: 9745277
# Q20 bases: 9644074(98.9615%)
# Q30 bases: 9348224(95.9257%)
#
# Filtering result:
# reads passed filter: 189890
# reads failed due to low quality: 4160
# reads failed due to too many N: 6
# reads failed due to too short: 3808
# reads with adapter trimmed: 191748
# bases trimmed due to adapters: 2233786
# reads corrected by overlap analysis: 16269
# bases corrected by overlap analysis: 27023
#
# Duplication rate: 27.7778%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 94669
# % of original read pairs: 95.691%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C10S_fastp.json
# HTML report: ./fastp_out/C10S_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C10S.R1.fastq -I 2_demultiplexed/ADD/C10S.R2.fastq -o 3_qc/ADD/C10S.R1.fastq -O 3_qc/ADD/C10S.R2.fastq --unpaired1 3_qc/ADD/C10S_unpaired.R1.fastq --unpaired2 3_qc/ADD/C10S_unpaired.R2.fastq --failed_out 3_qc/ADD/C10S_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C10S_merged.fastq -w 6 -h ./fastp_out/C10S_fastp.html -j ./fastp_out/C10S_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 102284
# total bases: 15362625
# Q20 bases: 15006588(97.6824%)
# Q30 bases: 14361560(93.4838%)
#
# Read2 before filtering:
# total reads: 102284
# total bases: 15350153
# Q20 bases: 14961678(97.4692%)
# Q30 bases: 14259080(92.8921%)
#
# Merged and filtered:
# total reads: 94809
# total bases: 9725860
# Q20 bases: 9596765(98.6727%)
# Q30 bases: 9242574(95.0309%)
#
# Filtering result:
# reads passed filter: 190112
# reads failed due to low quality: 5956
# reads failed due to too many N: 2
# reads failed due to too short: 8498
# reads with adapter trimmed: 192338
# bases trimmed due to adapters: 2398024
# reads corrected by overlap analysis: 20060
# bases corrected by overlap analysis: 33622
#
# Duplication rate: 19.1176%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 94809
# % of original read pairs: 92.6919%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C1ot_fastp.json
# HTML report: ./fastp_out/C1ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C1ot.R1.fastq -I 2_demultiplexed/ADD/C1ot.R2.fastq -o 3_qc/ADD/C1ot.R1.fastq -O 3_qc/ADD/C1ot.R2.fastq --unpaired1 3_qc/ADD/C1ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/C1ot_unpaired.R2.fastq --failed_out 3_qc/ADD/C1ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C1ot_merged.fastq -w 6 -h ./fastp_out/C1ot_fastp.html -j ./fastp_out/C1ot_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 72528
# total bases: 9258006
# Q20 bases: 9002547(97.2407%)
# Q30 bases: 8596404(92.8537%)
#
# Read2 before filtering:
# total reads: 72528
# total bases: 9170933
# Q20 bases: 8961087(97.7118%)
# Q30 bases: 8588768(93.6521%)
#
# Merged and filtered:
# total reads: 48743
# total bases: 5019335
# Q20 bases: 4959731(98.8125%)
# Q30 bases: 4791006(95.451%)
#
# Filtering result:
# reads passed filter: 107508
# reads failed due to low quality: 6902
# reads failed due to too many N: 0
# reads failed due to too short: 30646
# reads with adapter trimmed: 99586
# bases trimmed due to adapters: 1152346
# reads corrected by overlap analysis: 9209
# bases corrected by overlap analysis: 15807
#
# Duplication rate: 27.7311%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 48743
# % of original read pairs: 67.2058%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C2ot_fastp.json
# HTML report: ./fastp_out/C2ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C2ot.R1.fastq -I 2_demultiplexed/ADD/C2ot.R2.fastq -o 3_qc/ADD/C2ot.R1.fastq -O 3_qc/ADD/C2ot.R2.fastq --unpaired1 3_qc/ADD/C2ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/C2ot_unpaired.R2.fastq --failed_out 3_qc/ADD/C2ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C2ot_merged.fastq -w 6 -h ./fastp_out/C2ot_fastp.html -j ./fastp_out/C2ot_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 37664
# total bases: 4972421
# Q20 bases: 4843645(97.4102%)
# Q30 bases: 4630045(93.1145%)
#
# Read2 before filtering:
# total reads: 37664
# total bases: 4959008
# Q20 bases: 4845215(97.7053%)
# Q30 bases: 4647623(93.7208%)
#
# Merged and filtered:
# total reads: 26864
# total bases: 2773017
# Q20 bases: 2740931(98.8429%)
# Q30 bases: 2649159(95.5335%)
#
# Filtering result:
# reads passed filter: 58166
# reads failed due to low quality: 3218
# reads failed due to too many N: 0
# reads failed due to too short: 13944
# reads with adapter trimmed: 55548
# bases trimmed due to adapters: 585245
# reads corrected by overlap analysis: 4561
# bases corrected by overlap analysis: 7805
#
# Duplication rate: 20.202%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 26864
# % of original read pairs: 71.3254%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C3ot_fastp.json
# HTML report: ./fastp_out/C3ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C3ot.R1.fastq -I 2_demultiplexed/ADD/C3ot.R2.fastq -o 3_qc/ADD/C3ot.R1.fastq -O 3_qc/ADD/C3ot.R2.fastq --unpaired1 3_qc/ADD/C3ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/C3ot_unpaired.R2.fastq --failed_out 3_qc/ADD/C3ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C3ot_merged.fastq -w 6 -h ./fastp_out/C3ot_fastp.html -j ./fastp_out/C3ot_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 64656
# total bases: 5015511
# Q20 bases: 4763339(94.9722%)
# Q30 bases: 4467476(89.0732%)
#
# Read2 before filtering:
# total reads: 64656
# total bases: 4853911
# Q20 bases: 4708943(97.0134%)
# Q30 bases: 4511010(92.9356%)
#
# Merged and filtered:
# total reads: 11324
# total bases: 1175413
# Q20 bases: 1161393(98.8072%)
# Q30 bases: 1121489(95.4123%)
#
# Filtering result:
# reads passed filter: 22724
# reads failed due to low quality: 10220
# reads failed due to too many N: 2
# reads failed due to too short: 96366
# reads with adapter trimmed: 22942
# bases trimmed due to adapters: 243619
# reads corrected by overlap analysis: 2169
# bases corrected by overlap analysis: 3690
#
# Duplication rate: 28.125%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 11324
# % of original read pairs: 17.5142%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C45S_fastp.json
# HTML report: ./fastp_out/C45S_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C45S.R1.fastq -I 2_demultiplexed/ADD/C45S.R2.fastq -o 3_qc/ADD/C45S.R1.fastq -O 3_qc/ADD/C45S.R2.fastq --unpaired1 3_qc/ADD/C45S_unpaired.R1.fastq --unpaired2 3_qc/ADD/C45S_unpaired.R2.fastq --failed_out 3_qc/ADD/C45S_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C45S_merged.fastq -w 6 -h ./fastp_out/C45S_fastp.html -j ./fastp_out/C45S_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 41216
# total bases: 4425559
# Q20 bases: 4213070(95.1986%)
# Q30 bases: 3969384(89.6923%)
#
# Read2 before filtering:
# total reads: 41216
# total bases: 4251474
# Q20 bases: 4133315(97.2208%)
# Q30 bases: 3947255(92.8444%)
#
# Merged and filtered:
# total reads: 17439
# total bases: 1795907
# Q20 bases: 1773621(98.7591%)
# Q30 bases: 1711191(95.2828%)
#
# Filtering result:
# reads passed filter: 35062
# reads failed due to low quality: 7422
# reads failed due to too many N: 2
# reads failed due to too short: 39946
# reads with adapter trimmed: 35354
# bases trimmed due to adapters: 443233
# reads corrected by overlap analysis: 3488
# bases corrected by overlap analysis: 5777
#
# Duplication rate: 12.8205%
#
# Insert size peak (evaluated by paired-end reads): 144
#
# Read pairs merged: 17439
# % of original read pairs: 42.3112%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C47S_fastp.json
# HTML report: ./fastp_out/C47S_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C47S.R1.fastq -I 2_demultiplexed/ADD/C47S.R2.fastq -o 3_qc/ADD/C47S.R1.fastq -O 3_qc/ADD/C47S.R2.fastq --unpaired1 3_qc/ADD/C47S_unpaired.R1.fastq --unpaired2 3_qc/ADD/C47S_unpaired.R2.fastq --failed_out 3_qc/ADD/C47S_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C47S_merged.fastq -w 6 -h ./fastp_out/C47S_fastp.html -j ./fastp_out/C47S_fastp.json
# fastp v0.20.0, time used: 0 seconds
# Read1 before filtering:
# total reads: 47528
# total bases: 6759687
# Q20 bases: 6574897(97.2663%)
# Q30 bases: 6255027(92.5343%)
#
# Read2 before filtering:
# total reads: 47528
# total bases: 6739182
# Q20 bases: 6564899(97.4139%)
# Q30 bases: 6255541(92.8234%)
#
# Merged and filtered:
# total reads: 30739
# total bases: 3128065
# Q20 bases: 3087778(98.7121%)
# Q30 bases: 2972188(95.0168%)
#
# Filtering result:
# reads passed filter: 81616
# reads failed due to low quality: 4398
# reads failed due to too many N: 2
# reads failed due to too short: 9040
# reads with adapter trimmed: 64150
# bases trimmed due to adapters: 810758
# reads corrected by overlap analysis: 6228
# bases corrected by overlap analysis: 10492
#
# Duplication rate: 26.3889%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 30739
# % of original read pairs: 64.6756%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C4ot_fastp.json
# HTML report: ./fastp_out/C4ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C4ot.R1.fastq -I 2_demultiplexed/ADD/C4ot.R2.fastq -o 3_qc/ADD/C4ot.R1.fastq -O 3_qc/ADD/C4ot.R2.fastq --unpaired1 3_qc/ADD/C4ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/C4ot_unpaired.R2.fastq --failed_out 3_qc/ADD/C4ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C4ot_merged.fastq -w 6 -h ./fastp_out/C4ot_fastp.html -j ./fastp_out/C4ot_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 6376
# total bases: 340264
# Q20 bases: 321411(94.4593%)
# Q30 bases: 300408(88.2867%)
#
# Read2 before filtering:
# total reads: 6376
# total bases: 325561
# Q20 bases: 313730(96.366%)
# Q30 bases: 299626(92.0338%)
#
# Merged and filtered:
# total reads: 43
# total bases: 4585
# Q20 bases: 4527(98.735%)
# Q30 bases: 4372(95.3544%)
#
# Filtering result:
# reads passed filter: 584
# reads failed due to low quality: 1012
# reads failed due to too many N: 0
# reads failed due to too short: 11156
# reads with adapter trimmed: 112
# bases trimmed due to adapters: 1266
# reads corrected by overlap analysis: 13
# bases corrected by overlap analysis: 18
#
# Duplication rate: 5.88235%
#
# Insert size peak (evaluated by paired-end reads): 156
#
# Read pairs merged: 43
# % of original read pairs: 0.674404%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C50S_fastp.json
# HTML report: ./fastp_out/C50S_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C50S.R1.fastq -I 2_demultiplexed/ADD/C50S.R2.fastq -o 3_qc/ADD/C50S.R1.fastq -O 3_qc/ADD/C50S.R2.fastq --unpaired1 3_qc/ADD/C50S_unpaired.R1.fastq --unpaired2 3_qc/ADD/C50S_unpaired.R2.fastq --failed_out 3_qc/ADD/C50S_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C50S_merged.fastq -w 6 -h ./fastp_out/C50S_fastp.html -j ./fastp_out/C50S_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 211593
# total bases: 32217540
# Q20 bases: 31637857(98.2007%)
# Q30 bases: 30498914(94.6656%)
#
# Read2 before filtering:
# total reads: 211593
# total bases: 32205303
# Q20 bases: 31567359(98.0191%)
# Q30 bases: 30336073(94.1959%)
#
# Merged and filtered:
# total reads: 201168
# total bases: 20704823
# Q20 bases: 20480809(98.9181%)
# Q30 bases: 19839200(95.8192%)
#
# Filtering result:
# reads passed filter: 405996
# reads failed due to low quality: 8106
# reads failed due to too many N: 6
# reads failed due to too short: 9078
# reads with adapter trimmed: 406370
# bases trimmed due to adapters: 4714636
# reads corrected by overlap analysis: 34391
# bases corrected by overlap analysis: 56087
#
# Duplication rate: 49.5192%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 201168
# % of original read pairs: 95.0731%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C5ot_fastp.json
# HTML report: ./fastp_out/C5ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/C5ot.R1.fastq -I 2_demultiplexed/ADD/C5ot.R2.fastq -o 3_qc/ADD/C5ot.R1.fastq -O 3_qc/ADD/C5ot.R2.fastq --unpaired1 3_qc/ADD/C5ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/C5ot_unpaired.R2.fastq --failed_out 3_qc/ADD/C5ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/C5ot_merged.fastq -w 6 -h ./fastp_out/C5ot_fastp.html -j ./fastp_out/C5ot_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 17633
# total bases: 1451194
# Q20 bases: 1336991(92.1304%)
# Q30 bases: 1232133(84.9048%)
#
# Read2 before filtering:
# total reads: 17633
# total bases: 1342701
# Q20 bases: 1270805(94.6454%)
# Q30 bases: 1191357(88.7284%)
#
# Merged and filtered:
# total reads: 3144
# total bases: 318627
# Q20 bases: 314617(98.7415%)
# Q30 bases: 303267(95.1793%)
#
# Filtering result:
# reads passed filter: 6318
# reads failed due to low quality: 5178
# reads failed due to too many N: 0
# reads failed due to too short: 23770
# reads with adapter trimmed: 6356
# bases trimmed due to adapters: 79654
# reads corrected by overlap analysis: 740
# bases corrected by overlap analysis: 1243
#
# Duplication rate: 25.3333%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 3144
# % of original read pairs: 17.8302%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/N1ot_fastp.json
# HTML report: ./fastp_out/N1ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/N1ot.R1.fastq -I 2_demultiplexed/ADD/N1ot.R2.fastq -o 3_qc/ADD/N1ot.R1.fastq -O 3_qc/ADD/N1ot.R2.fastq --unpaired1 3_qc/ADD/N1ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/N1ot_unpaired.R2.fastq --failed_out 3_qc/ADD/N1ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/N1ot_merged.fastq -w 6 -h ./fastp_out/N1ot_fastp.html -j ./fastp_out/N1ot_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 93945
# total bases: 14321443
# Q20 bases: 13988977(97.6785%)
# Q30 bases: 13375390(93.3942%)
#
# Read2 before filtering:
# total reads: 93945
# total bases: 14338344
# Q20 bases: 13889530(96.8698%)
# Q30 bases: 13119050(91.4963%)
#
# Merged and filtered:
# total reads: 90573
# total bases: 9237848
# Q20 bases: 9119416(98.718%)
# Q30 bases: 8781201(95.0568%)
#
# Filtering result:
# reads passed filter: 181574
# reads failed due to low quality: 5070
# reads failed due to too many N: 0
# reads failed due to too short: 1246
# reads with adapter trimmed: 183610
# bases trimmed due to adapters: 1981324
# reads corrected by overlap analysis: 18931
# bases corrected by overlap analysis: 31159
#
# Duplication rate: 81.6794%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 90573
# % of original read pairs: 96.4107%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/P1ot_fastp.json
# HTML report: ./fastp_out/P1ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/P1ot.R1.fastq -I 2_demultiplexed/ADD/P1ot.R2.fastq -o 3_qc/ADD/P1ot.R1.fastq -O 3_qc/ADD/P1ot.R2.fastq --unpaired1 3_qc/ADD/P1ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/P1ot_unpaired.R2.fastq --failed_out 3_qc/ADD/P1ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/P1ot_merged.fastq -w 6 -h ./fastp_out/P1ot_fastp.html -j ./fastp_out/P1ot_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 345223
# total bases: 52881876
# Q20 bases: 51622597(97.6187%)
# Q30 bases: 49292367(93.2122%)
#
# Read2 before filtering:
# total reads: 345223
# total bases: 52854182
# Q20 bases: 51346444(97.1474%)
# Q30 bases: 48633213(92.0139%)
#
# Merged and filtered:
# total reads: 335614
# total bases: 34230474
# Q20 bases: 33761896(98.6311%)
# Q30 bases: 32456463(94.8175%)
#
# Filtering result:
# reads passed filter: 672508
# reads failed due to low quality: 17892
# reads failed due to too many N: 8
# reads failed due to too short: 38
# reads with adapter trimmed: 681328
# bases trimmed due to adapters: 7335833
# reads corrected by overlap analysis: 70030
# bases corrected by overlap analysis: 115773
#
# Duplication rate: 82.9582%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 335614
# % of original read pairs: 97.2166%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/POSI_fastp.json
# HTML report: ./fastp_out/POSI_fastp.html
#
# fastp -i 2_demultiplexed/ADD/POSI.R1.fastq -I 2_demultiplexed/ADD/POSI.R2.fastq -o 3_qc/ADD/POSI.R1.fastq -O 3_qc/ADD/POSI.R2.fastq --unpaired1 3_qc/ADD/POSI_unpaired.R1.fastq --unpaired2 3_qc/ADD/POSI_unpaired.R2.fastq --failed_out 3_qc/ADD/POSI_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/POSI_merged.fastq -w 6 -h ./fastp_out/POSI_fastp.html -j ./fastp_out/POSI_fastp.json
# fastp v0.20.0, time used: 3 seconds
# Read1 before filtering:
# total reads: 39786
# total bases: 4243225
# Q20 bases: 4096388(96.5395%)
# Q30 bases: 3900358(91.9197%)
#
# Read2 before filtering:
# total reads: 39786
# total bases: 4222005
# Q20 bases: 4055912(96.066%)
# Q30 bases: 3847263(91.1241%)
#
# Merged and filtered:
# total reads: 20986
# total bases: 2161102
# Q20 bases: 2137599(98.9125%)
# Q30 bases: 2070681(95.816%)
#
# Filtering result:
# reads passed filter: 42398
# reads failed due to low quality: 6512
# reads failed due to too many N: 0
# reads failed due to too short: 30662
# reads with adapter trimmed: 42402
# bases trimmed due to adapters: 494318
# reads corrected by overlap analysis: 3994
# bases corrected by overlap analysis: 6570
#
# Duplication rate: 27.7778%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 20986
# % of original read pairs: 52.7472%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/RS11_fastp.json
# HTML report: ./fastp_out/RS11_fastp.html
#
# fastp -i 2_demultiplexed/ADD/RS11.R1.fastq -I 2_demultiplexed/ADD/RS11.R2.fastq -o 3_qc/ADD/RS11.R1.fastq -O 3_qc/ADD/RS11.R2.fastq --unpaired1 3_qc/ADD/RS11_unpaired.R1.fastq --unpaired2 3_qc/ADD/RS11_unpaired.R2.fastq --failed_out 3_qc/ADD/RS11_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/RS11_merged.fastq -w 6 -h ./fastp_out/RS11_fastp.html -j ./fastp_out/RS11_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 20443
# total bases: 1756854
# Q20 bases: 1680188(95.6362%)
# Q30 bases: 1581125(89.9975%)
#
# Read2 before filtering:
# total reads: 20443
# total bases: 1717480
# Q20 bases: 1657203(96.4904%)
# Q30 bases: 1571733(91.5139%)
#
# Merged and filtered:
# total reads: 7198
# total bases: 747386
# Q20 bases: 737020(98.613%)
# Q30 bases: 709186(94.8889%)
#
# Filtering result:
# reads passed filter: 15198
# reads failed due to low quality: 2876
# reads failed due to too many N: 0
# reads failed due to too short: 22812
# reads with adapter trimmed: 14704
# bases trimmed due to adapters: 158367
# reads corrected by overlap analysis: 1590
# bases corrected by overlap analysis: 2734
#
# Duplication rate: 25.6098%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 7198
# % of original read pairs: 35.2101%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/RS15_fastp.json
# HTML report: ./fastp_out/RS15_fastp.html
#
# fastp -i 2_demultiplexed/ADD/RS15.R1.fastq -I 2_demultiplexed/ADD/RS15.R2.fastq -o 3_qc/ADD/RS15.R1.fastq -O 3_qc/ADD/RS15.R2.fastq --unpaired1 3_qc/ADD/RS15_unpaired.R1.fastq --unpaired2 3_qc/ADD/RS15_unpaired.R2.fastq --failed_out 3_qc/ADD/RS15_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/RS15_merged.fastq -w 6 -h ./fastp_out/RS15_fastp.html -j ./fastp_out/RS15_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 19286
# total bases: 1841423
# Q20 bases: 1774497(96.3655%)
# Q30 bases: 1687796(91.6572%)
#
# Read2 before filtering:
# total reads: 19286
# total bases: 1864195
# Q20 bases: 1769786(94.9357%)
# Q30 bases: 1670097(89.5881%)
#
# Merged and filtered:
# total reads: 8060
# total bases: 830072
# Q20 bases: 820542(98.8519%)
# Q30 bases: 794072(95.663%)
#
# Filtering result:
# reads passed filter: 16178
# reads failed due to low quality: 3670
# reads failed due to too many N: 0
# reads failed due to too short: 18724
# reads with adapter trimmed: 16250
# bases trimmed due to adapters: 205160
# reads corrected by overlap analysis: 1596
# bases corrected by overlap analysis: 2579
#
# Duplication rate: 27.2727%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 8060
# % of original read pairs: 41.792%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/RS19_fastp.json
# HTML report: ./fastp_out/RS19_fastp.html
#
# fastp -i 2_demultiplexed/ADD/RS19.R1.fastq -I 2_demultiplexed/ADD/RS19.R2.fastq -o 3_qc/ADD/RS19.R1.fastq -O 3_qc/ADD/RS19.R2.fastq --unpaired1 3_qc/ADD/RS19_unpaired.R1.fastq --unpaired2 3_qc/ADD/RS19_unpaired.R2.fastq --failed_out 3_qc/ADD/RS19_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/RS19_merged.fastq -w 6 -h ./fastp_out/RS19_fastp.html -j ./fastp_out/RS19_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 79728
# total bases: 6875497
# Q20 bases: 6603787(96.0481%)
# Q30 bases: 6249913(90.9013%)
#
# Read2 before filtering:
# total reads: 79728
# total bases: 6735175
# Q20 bases: 6530683(96.9638%)
# Q30 bases: 6234131(92.5608%)
#
# Merged and filtered:
# total reads: 20327
# total bases: 2093074
# Q20 bases: 2071301(98.9598%)
# Q30 bases: 2006891(95.8825%)
#
# Filtering result:
# reads passed filter: 41076
# reads failed due to low quality: 11664
# reads failed due to too many N: 0
# reads failed due to too short: 106716
# reads with adapter trimmed: 41040
# bases trimmed due to adapters: 477184
# reads corrected by overlap analysis: 3915
# bases corrected by overlap analysis: 6348
#
# Duplication rate: 13.7931%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 20327
# % of original read pairs: 25.4954%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/RS31_fastp.json
# HTML report: ./fastp_out/RS31_fastp.html
#
# fastp -i 2_demultiplexed/ADD/RS31.R1.fastq -I 2_demultiplexed/ADD/RS31.R2.fastq -o 3_qc/ADD/RS31.R1.fastq -O 3_qc/ADD/RS31.R2.fastq --unpaired1 3_qc/ADD/RS31_unpaired.R1.fastq --unpaired2 3_qc/ADD/RS31_unpaired.R2.fastq --failed_out 3_qc/ADD/RS31_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/RS31_merged.fastq -w 6 -h ./fastp_out/RS31_fastp.html -j ./fastp_out/RS31_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 29447
# total bases: 3543799
# Q20 bases: 3354679(94.6634%)
# Q30 bases: 3145692(88.7661%)
#
# Read2 before filtering:
# total reads: 29447
# total bases: 3334324
# Q20 bases: 3232476(96.9455%)
# Q30 bases: 3069659(92.0624%)
#
# Merged and filtered:
# total reads: 15223
# total bases: 1570287
# Q20 bases: 1551394(98.7968%)
# Q30 bases: 1498167(95.4072%)
#
# Filtering result:
# reads passed filter: 34746
# reads failed due to low quality: 5920
# reads failed due to too many N: 4
# reads failed due to too short: 18224
# reads with adapter trimmed: 35020
# bases trimmed due to adapters: 349943
# reads corrected by overlap analysis: 3768
# bases corrected by overlap analysis: 6353
#
# Duplication rate: 32.967%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 15223
# % of original read pairs: 51.6963%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/RS49_fastp.json
# HTML report: ./fastp_out/RS49_fastp.html
#
# fastp -i 2_demultiplexed/ADD/RS49.R1.fastq -I 2_demultiplexed/ADD/RS49.R2.fastq -o 3_qc/ADD/RS49.R1.fastq -O 3_qc/ADD/RS49.R2.fastq --unpaired1 3_qc/ADD/RS49_unpaired.R1.fastq --unpaired2 3_qc/ADD/RS49_unpaired.R2.fastq --failed_out 3_qc/ADD/RS49_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/RS49_merged.fastq -w 6 -h ./fastp_out/RS49_fastp.html -j ./fastp_out/RS49_fastp.json
# fastp v0.20.0, time used: 0 seconds
# Read1 before filtering:
# total reads: 93345
# total bases: 8226268
# Q20 bases: 7559461(91.8942%)
# Q30 bases: 6951558(84.5044%)
#
# Read2 before filtering:
# total reads: 93345
# total bases: 7530856
# Q20 bases: 7275883(96.6143%)
# Q30 bases: 6940021(92.1545%)
#
# Merged and filtered:
# total reads: 19448
# total bases: 2003011
# Q20 bases: 1979807(98.8415%)
# Q30 bases: 1912791(95.4958%)
#
# Filtering result:
# reads passed filter: 39732
# reads failed due to low quality: 24304
# reads failed due to too many N: 0
# reads failed due to too short: 122654
# reads with adapter trimmed: 39604
# bases trimmed due to adapters: 500441
# reads corrected by overlap analysis: 3985
# bases corrected by overlap analysis: 6645
#
# Duplication rate: 15%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 19448
# % of original read pairs: 20.8345%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/RS51_fastp.json
# HTML report: ./fastp_out/RS51_fastp.html
#
# fastp -i 2_demultiplexed/ADD/RS51.R1.fastq -I 2_demultiplexed/ADD/RS51.R2.fastq -o 3_qc/ADD/RS51.R1.fastq -O 3_qc/ADD/RS51.R2.fastq --unpaired1 3_qc/ADD/RS51_unpaired.R1.fastq --unpaired2 3_qc/ADD/RS51_unpaired.R2.fastq --failed_out 3_qc/ADD/RS51_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/RS51_merged.fastq -w 6 -h ./fastp_out/RS51_fastp.html -j ./fastp_out/RS51_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 139473
# total bases: 21079426
# Q20 bases: 20597396(97.7133%)
# Q30 bases: 19737321(93.6331%)
#
# Read2 before filtering:
# total reads: 139473
# total bases: 21030712
# Q20 bases: 20479843(97.3806%)
# Q30 bases: 19503128(92.7364%)
#
# Merged and filtered:
# total reads: 130824
# total bases: 13585204
# Q20 bases: 13417439(98.7651%)
# Q30 bases: 12949274(95.319%)
#
# Filtering result:
# reads passed filter: 262912
# reads failed due to low quality: 7042
# reads failed due to too many N: 6
# reads failed due to too short: 8986
# reads with adapter trimmed: 264858
# bases trimmed due to adapters: 2839847
# reads corrected by overlap analysis: 26746
# bases corrected by overlap analysis: 45957
#
# Duplication rate: 13.6752%
#
# Insert size peak (evaluated by paired-end reads): 144
#
# Read pairs merged: 130824
# % of original read pairs: 93.7988%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/S1ot_fastp.json
# HTML report: ./fastp_out/S1ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/S1ot.R1.fastq -I 2_demultiplexed/ADD/S1ot.R2.fastq -o 3_qc/ADD/S1ot.R1.fastq -O 3_qc/ADD/S1ot.R2.fastq --unpaired1 3_qc/ADD/S1ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/S1ot_unpaired.R2.fastq --failed_out 3_qc/ADD/S1ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/S1ot_merged.fastq -w 6 -h ./fastp_out/S1ot_fastp.html -j ./fastp_out/S1ot_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 55578
# total bases: 7570838
# Q20 bases: 7280026(96.1588%)
# Q30 bases: 6888387(90.9858%)
#
# Read2 before filtering:
# total reads: 55578
# total bases: 7356101
# Q20 bases: 7173969(97.5241%)
# Q30 bases: 6846652(93.0745%)
#
# Merged and filtered:
# total reads: 41383
# total bases: 4298015
# Q20 bases: 4238730(98.6206%)
# Q30 bases: 4076115(94.8372%)
#
# Filtering result:
# reads passed filter: 83780
# reads failed due to low quality: 7082
# reads failed due to too many N: 2
# reads failed due to too short: 20292
# reads with adapter trimmed: 84526
# bases trimmed due to adapters: 1074849
# reads corrected by overlap analysis: 8867
# bases corrected by overlap analysis: 15073
#
# Duplication rate: 31.5315%
#
# Insert size peak (evaluated by paired-end reads): 144
#
# Read pairs merged: 41383
# % of original read pairs: 74.4593%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/S3ot_fastp.json
# HTML report: ./fastp_out/S3ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/S3ot.R1.fastq -I 2_demultiplexed/ADD/S3ot.R2.fastq -o 3_qc/ADD/S3ot.R1.fastq -O 3_qc/ADD/S3ot.R2.fastq --unpaired1 3_qc/ADD/S3ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/S3ot_unpaired.R2.fastq --failed_out 3_qc/ADD/S3ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/S3ot_merged.fastq -w 6 -h ./fastp_out/S3ot_fastp.html -j ./fastp_out/S3ot_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 53082
# total bases: 6831407
# Q20 bases: 6610346(96.764%)
# Q30 bases: 6261826(91.6623%)
#
# Read2 before filtering:
# total reads: 53082
# total bases: 6771465
# Q20 bases: 6567760(96.9917%)
# Q30 bases: 6220377(91.8616%)
#
# Merged and filtered:
# total reads: 34342
# total bases: 3570128
# Q20 bases: 3517886(98.5367%)
# Q30 bases: 3377873(94.6149%)
#
# Filtering result:
# reads passed filter: 79604
# reads failed due to low quality: 5428
# reads failed due to too many N: 2
# reads failed due to too short: 21130
# reads with adapter trimmed: 70342
# bases trimmed due to adapters: 830280
# reads corrected by overlap analysis: 7967
# bases corrected by overlap analysis: 13725
#
# Duplication rate: 31.7308%
#
# Insert size peak (evaluated by paired-end reads): 144
#
# Read pairs merged: 34342
# % of original read pairs: 64.6961%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/S5ot_fastp.json
# HTML report: ./fastp_out/S5ot_fastp.html
#
# fastp -i 2_demultiplexed/ADD/S5ot.R1.fastq -I 2_demultiplexed/ADD/S5ot.R2.fastq -o 3_qc/ADD/S5ot.R1.fastq -O 3_qc/ADD/S5ot.R2.fastq --unpaired1 3_qc/ADD/S5ot_unpaired.R1.fastq --unpaired2 3_qc/ADD/S5ot_unpaired.R2.fastq --failed_out 3_qc/ADD/S5ot_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/ADD/S5ot_merged.fastq -w 6 -h ./fastp_out/S5ot_fastp.html -j ./fastp_out/S5ot_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 77605
# total bases: 11991458
# Q20 bases: 11722883(97.7603%)
# Q30 bases: 11230012(93.6501%)
#
# Read2 before filtering:
# total reads: 77605
# total bases: 11994898
# Q20 bases: 11715398(97.6698%)
# Q30 bases: 11206978(93.4312%)
#
# Merged and filtered:
# total reads: 74397
# total bases: 7631187
# Q20 bases: 7535470(98.7457%)
# Q30 bases: 7268571(95.2482%)
#
# Filtering result:
# reads passed filter: 149648
# reads failed due to low quality: 4178
# reads failed due to too many N: 8
# reads failed due to too short: 1376
# reads with adapter trimmed: 151768
# bases trimmed due to adapters: 1891927
# reads corrected by overlap analysis: 14044
# bases corrected by overlap analysis: 23270
#
# Duplication rate: 25.5814%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 74397
# % of original read pairs: 95.8662%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A01W_fastp.json
# HTML report: ./fastp_out/A01W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A01W.R1.fastq -I 2_demultiplexed/AW1/A01W.R2.fastq -o 3_qc/AW1/A01W.R1.fastq -O 3_qc/AW1/A01W.R2.fastq --unpaired1 3_qc/AW1/A01W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A01W_unpaired.R2.fastq --failed_out 3_qc/AW1/A01W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A01W_merged.fastq -w 6 -h ./fastp_out/A01W_fastp.html -j ./fastp_out/A01W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 168890
# total bases: 25977656
# Q20 bases: 25412061(97.8228%)
# Q30 bases: 24373767(93.8259%)
#
# Read2 before filtering:
# total reads: 168890
# total bases: 25956997
# Q20 bases: 25349078(97.658%)
# Q30 bases: 24252783(93.4345%)
#
# Merged and filtered:
# total reads: 161386
# total bases: 16546526
# Q20 bases: 16348755(98.8048%)
# Q30 bases: 15790150(95.4288%)
#
# Filtering result:
# reads passed filter: 326090
# reads failed due to low quality: 9120
# reads failed due to too many N: 6
# reads failed due to too short: 2564
# reads with adapter trimmed: 329868
# bases trimmed due to adapters: 3835240
# reads corrected by overlap analysis: 28512
# bases corrected by overlap analysis: 48219
#
# Duplication rate: 48.2143%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 161386
# % of original read pairs: 95.5569%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A02W_fastp.json
# HTML report: ./fastp_out/A02W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A02W.R1.fastq -I 2_demultiplexed/AW1/A02W.R2.fastq -o 3_qc/AW1/A02W.R1.fastq -O 3_qc/AW1/A02W.R2.fastq --unpaired1 3_qc/AW1/A02W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A02W_unpaired.R2.fastq --failed_out 3_qc/AW1/A02W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A02W_merged.fastq -w 6 -h ./fastp_out/A02W_fastp.html -j ./fastp_out/A02W_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 108337
# total bases: 16569772
# Q20 bases: 16229849(97.9485%)
# Q30 bases: 15559695(93.9041%)
#
# Read2 before filtering:
# total reads: 108337
# total bases: 16561960
# Q20 bases: 16165507(97.6062%)
# Q30 bases: 15400864(92.9894%)
#
# Merged and filtered:
# total reads: 104963
# total bases: 10800106
# Q20 bases: 10677101(98.8611%)
# Q30 bases: 10319146(95.5467%)
#
# Filtering result:
# reads passed filter: 210116
# reads failed due to low quality: 4506
# reads failed due to too many N: 2
# reads failed due to too short: 2050
# reads with adapter trimmed: 212620
# bases trimmed due to adapters: 2263167
# reads corrected by overlap analysis: 17222
# bases corrected by overlap analysis: 28398
#
# Duplication rate: 39.3548%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 104963
# % of original read pairs: 96.8856%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A03W_fastp.json
# HTML report: ./fastp_out/A03W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A03W.R1.fastq -I 2_demultiplexed/AW1/A03W.R2.fastq -o 3_qc/AW1/A03W.R1.fastq -O 3_qc/AW1/A03W.R2.fastq --unpaired1 3_qc/AW1/A03W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A03W_unpaired.R2.fastq --failed_out 3_qc/AW1/A03W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A03W_merged.fastq -w 6 -h ./fastp_out/A03W_fastp.html -j ./fastp_out/A03W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 97383
# total bases: 15063982
# Q20 bases: 14730419(97.7857%)
# Q30 bases: 14090624(93.5385%)
#
# Read2 before filtering:
# total reads: 97383
# total bases: 15060405
# Q20 bases: 14669716(97.4059%)
# Q30 bases: 13935956(92.5337%)
#
# Merged and filtered:
# total reads: 93495
# total bases: 9621699
# Q20 bases: 9508801(98.8266%)
# Q30 bases: 9183966(95.4506%)
#
# Filtering result:
# reads passed filter: 187810
# reads failed due to low quality: 4776
# reads failed due to too many N: 4
# reads failed due to too short: 2176
# reads with adapter trimmed: 189966
# bases trimmed due to adapters: 2413035
# reads corrected by overlap analysis: 16292
# bases corrected by overlap analysis: 27147
#
# Duplication rate: 55.8935%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 93495
# % of original read pairs: 96.0075%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A04W_fastp.json
# HTML report: ./fastp_out/A04W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A04W.R1.fastq -I 2_demultiplexed/AW1/A04W.R2.fastq -o 3_qc/AW1/A04W.R1.fastq -O 3_qc/AW1/A04W.R2.fastq --unpaired1 3_qc/AW1/A04W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A04W_unpaired.R2.fastq --failed_out 3_qc/AW1/A04W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A04W_merged.fastq -w 6 -h ./fastp_out/A04W_fastp.html -j ./fastp_out/A04W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 179756
# total bases: 27263949
# Q20 bases: 26685215(97.8773%)
# Q30 bases: 25627954(93.9994%)
#
# Read2 before filtering:
# total reads: 179756
# total bases: 27226711
# Q20 bases: 26594344(97.6774%)
# Q30 bases: 25439971(93.4375%)
#
# Merged and filtered:
# total reads: 168359
# total bases: 17278552
# Q20 bases: 17086025(98.8857%)
# Q30 bases: 16535170(95.6977%)
#
# Filtering result:
# reads passed filter: 339396
# reads failed due to low quality: 9136
# reads failed due to too many N: 4
# reads failed due to too short: 10976
# reads with adapter trimmed: 342660
# bases trimmed due to adapters: 3991346
# reads corrected by overlap analysis: 27493
# bases corrected by overlap analysis: 45575
#
# Duplication rate: 45.614%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 168359
# % of original read pairs: 93.6597%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A05W_fastp.json
# HTML report: ./fastp_out/A05W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A05W.R1.fastq -I 2_demultiplexed/AW1/A05W.R2.fastq -o 3_qc/AW1/A05W.R1.fastq -O 3_qc/AW1/A05W.R2.fastq --unpaired1 3_qc/AW1/A05W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A05W_unpaired.R2.fastq --failed_out 3_qc/AW1/A05W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A05W_merged.fastq -w 6 -h ./fastp_out/A05W_fastp.html -j ./fastp_out/A05W_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 130906
# total bases: 20119761
# Q20 bases: 19733975(98.0826%)
# Q30 bases: 18999084(94.43%)
#
# Read2 before filtering:
# total reads: 130906
# total bases: 20114249
# Q20 bases: 19605547(97.4709%)
# Q30 bases: 18680555(92.8722%)
#
# Merged and filtered:
# total reads: 127717
# total bases: 13148932
# Q20 bases: 13012058(98.959%)
# Q30 bases: 12613924(95.9312%)
#
# Filtering result:
# reads passed filter: 255788
# reads failed due to low quality: 5428
# reads failed due to too many N: 2
# reads failed due to too short: 594
# reads with adapter trimmed: 258744
# bases trimmed due to adapters: 2743559
# reads corrected by overlap analysis: 20206
# bases corrected by overlap analysis: 33673
#
# Duplication rate: 43.0233%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 127717
# % of original read pairs: 97.5639%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A06W_fastp.json
# HTML report: ./fastp_out/A06W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A06W.R1.fastq -I 2_demultiplexed/AW1/A06W.R2.fastq -o 3_qc/AW1/A06W.R1.fastq -O 3_qc/AW1/A06W.R2.fastq --unpaired1 3_qc/AW1/A06W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A06W_unpaired.R2.fastq --failed_out 3_qc/AW1/A06W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A06W_merged.fastq -w 6 -h ./fastp_out/A06W_fastp.html -j ./fastp_out/A06W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 180288
# total bases: 27888930
# Q20 bases: 27386658(98.199%)
# Q30 bases: 26404473(94.6773%)
#
# Read2 before filtering:
# total reads: 180288
# total bases: 27888997
# Q20 bases: 27361203(98.1075%)
# Q30 bases: 26331512(94.4154%)
#
# Merged and filtered:
# total reads: 174733
# total bases: 17974030
# Q20 bases: 17788629(98.9685%)
# Q30 bases: 17253056(95.9888%)
#
# Filtering result:
# reads passed filter: 349828
# reads failed due to low quality: 7234
# reads failed due to too many N: 4
# reads failed due to too short: 3510
# reads with adapter trimmed: 353904
# bases trimmed due to adapters: 4442828
# reads corrected by overlap analysis: 25206
# bases corrected by overlap analysis: 41395
#
# Duplication rate: 51.9337%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 174733
# % of original read pairs: 96.9188%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A07W_fastp.json
# HTML report: ./fastp_out/A07W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A07W.R1.fastq -I 2_demultiplexed/AW1/A07W.R2.fastq -o 3_qc/AW1/A07W.R1.fastq -O 3_qc/AW1/A07W.R2.fastq --unpaired1 3_qc/AW1/A07W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A07W_unpaired.R2.fastq --failed_out 3_qc/AW1/A07W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A07W_merged.fastq -w 6 -h ./fastp_out/A07W_fastp.html -j ./fastp_out/A07W_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 97166
# total bases: 14907144
# Q20 bases: 14633815(98.1665%)
# Q30 bases: 14104904(94.6184%)
#
# Read2 before filtering:
# total reads: 97166
# total bases: 14900569
# Q20 bases: 14562873(97.7337%)
# Q30 bases: 13937148(93.5343%)
#
# Merged and filtered:
# total reads: 94611
# total bases: 9740590
# Q20 bases: 9641301(98.9807%)
# Q30 bases: 9349410(95.984%)
#
# Filtering result:
# reads passed filter: 189510
# reads failed due to low quality: 3858
# reads failed due to too many N: 0
# reads failed due to too short: 964
# reads with adapter trimmed: 191422
# bases trimmed due to adapters: 2023650
# reads corrected by overlap analysis: 14138
# bases corrected by overlap analysis: 23456
#
# Duplication rate: 43.2749%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 94611
# % of original read pairs: 97.3705%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/A08W_fastp.json
# HTML report: ./fastp_out/A08W_fastp.html
#
# fastp -i 2_demultiplexed/AW1/A08W.R1.fastq -I 2_demultiplexed/AW1/A08W.R2.fastq -o 3_qc/AW1/A08W.R1.fastq -O 3_qc/AW1/A08W.R2.fastq --unpaired1 3_qc/AW1/A08W_unpaired.R1.fastq --unpaired2 3_qc/AW1/A08W_unpaired.R2.fastq --failed_out 3_qc/AW1/A08W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/AW1/A08W_merged.fastq -w 6 -h ./fastp_out/A08W_fastp.html -j ./fastp_out/A08W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 122727
# total bases: 18988678
# Q20 bases: 18628731(98.1044%)
# Q30 bases: 17903426(94.2847%)
#
# Read2 before filtering:
# total reads: 122727
# total bases: 19001079
# Q20 bases: 18567745(97.7194%)
# Q30 bases: 17726041(93.2897%)
#
# Merged and filtered:
# total reads: 119022
# total bases: 12252247
# Q20 bases: 12112919(98.8628%)
# Q30 bases: 11714768(95.6132%)
#
# Filtering result:
# reads passed filter: 238446
# reads failed due to low quality: 4762
# ...
# reads failed due to too many N: 2
# reads failed due to too short: 2210
# reads with adapter trimmed: 256858
# bases trimmed due to adapters: 2709674
# reads corrected by overlap analysis: 19894
# bases corrected by overlap analysis: 32471
#
# Duplication rate: 23.8095%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 126912
# % of original read pairs: 96.9186%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C48W_fastp.json
# HTML report: ./fastp_out/C48W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C48W.R1.fastq -I 2_demultiplexed/CW3/C48W.R2.fastq -o 3_qc/CW3/C48W.R1.fastq -O 3_qc/CW3/C48W.R2.fastq --unpaired1 3_qc/CW3/C48W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C48W_unpaired.R2.fastq --failed_out 3_qc/CW3/C48W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C48W_merged.fastq -w 6 -h ./fastp_out/C48W_fastp.html -j ./fastp_out/C48W_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 130003
# total bases: 19968564
# Q20 bases: 19675768(98.5337%)
# Q30 bases: 19064366(95.4719%)
#
# Read2 before filtering:
# total reads: 130003
# total bases: 20010400
# Q20 bases: 19527114(97.5848%)
# Q30 bases: 18636329(93.1332%)
#
# Merged and filtered:
# total reads: 124965
# total bases: 12815249
# Q20 bases: 12706591(99.1521%)
# Q30 bases: 12377070(96.5808%)
#
# Filtering result:
# reads passed filter: 251508
# reads failed due to low quality: 4430
# reads failed due to too many N: 8
# reads failed due to too short: 4060
# reads with adapter trimmed: 253308
# bases trimmed due to adapters: 3159988
# reads corrected by overlap analysis: 19243
# bases corrected by overlap analysis: 31311
#
# Duplication rate: 39.6825%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 124965
# % of original read pairs: 96.1247%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C49W_fastp.json
# HTML report: ./fastp_out/C49W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C49W.R1.fastq -I 2_demultiplexed/CW3/C49W.R2.fastq -o 3_qc/CW3/C49W.R1.fastq -O 3_qc/CW3/C49W.R2.fastq --unpaired1 3_qc/CW3/C49W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C49W_unpaired.R2.fastq --failed_out 3_qc/CW3/C49W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C49W_merged.fastq -w 6 -h ./fastp_out/C49W_fastp.html -j ./fastp_out/C49W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 251530
# total bases: 38479663
# Q20 bases: 37862806(98.3969%)
# Q30 bases: 36634014(95.2036%)
#
# Read2 before filtering:
# total reads: 251530
# total bases: 38535801
# Q20 bases: 37584212(97.5306%)
# Q30 bases: 35901505(93.164%)
#
# Merged and filtered:
# total reads: 242197
# total bases: 24810051
# Q20 bases: 24585478(99.0948%)
# Q30 bases: 23912501(96.3823%)
#
# Filtering result:
# reads passed filter: 488512
# reads failed due to low quality: 9854
# reads failed due to too many N: 4
# reads failed due to too short: 4690
# reads with adapter trimmed: 490328
# bases trimmed due to adapters: 5684871
# reads corrected by overlap analysis: 39105
# bases corrected by overlap analysis: 64340
#
# Duplication rate: 28.0576%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 242197
# % of original read pairs: 96.2895%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C50W_fastp.json
# HTML report: ./fastp_out/C50W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C50W.R1.fastq -I 2_demultiplexed/CW3/C50W.R2.fastq -o 3_qc/CW3/C50W.R1.fastq -O 3_qc/CW3/C50W.R2.fastq --unpaired1 3_qc/CW3/C50W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C50W_unpaired.R2.fastq --failed_out 3_qc/CW3/C50W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C50W_merged.fastq -w 6 -h ./fastp_out/C50W_fastp.html -j ./fastp_out/C50W_fastp.json
# fastp v0.20.0, time used: 3 seconds
# Read1 before filtering:
# total reads: 183500
# total bases: 27887650
# Q20 bases: 27366629(98.1317%)
# Q30 bases: 26346191(94.4726%)
#
# Read2 before filtering:
# total reads: 183500
# total bases: 27911057
# Q20 bases: 27117879(97.1582%)
# Q30 bases: 25723165(92.1612%)
#
# Merged and filtered:
# total reads: 176455
# total bases: 18079668
# Q20 bases: 17898419(98.9975%)
# Q30 bases: 17354941(95.9915%)
#
# Filtering result:
# reads passed filter: 354454
# reads failed due to low quality: 8340
# reads failed due to too many N: 4
# reads failed due to too short: 4202
# reads with adapter trimmed: 357936
# bases trimmed due to adapters: 3799010
# reads corrected by overlap analysis: 30485
# bases corrected by overlap analysis: 50621
#
# Duplication rate: 50.7692%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 176455
# % of original read pairs: 96.1608%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C51W_fastp.json
# HTML report: ./fastp_out/C51W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C51W.R1.fastq -I 2_demultiplexed/CW3/C51W.R2.fastq -o 3_qc/CW3/C51W.R1.fastq -O 3_qc/CW3/C51W.R2.fastq --unpaired1 3_qc/CW3/C51W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C51W_unpaired.R2.fastq --failed_out 3_qc/CW3/C51W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C51W_merged.fastq -w 6 -h ./fastp_out/C51W_fastp.html -j ./fastp_out/C51W_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 117782
# total bases: 15776616
# Q20 bases: 15477759(98.1057%)
# Q30 bases: 14940555(94.7006%)
#
# Read2 before filtering:
# total reads: 117782
# total bases: 15758872
# Q20 bases: 15344252(97.369%)
# Q30 bases: 14647347(92.9467%)
#
# Merged and filtered:
# total reads: 89607
# total bases: 9187842
# Q20 bases: 9106967(99.1198%)
# Q30 bases: 8863581(96.4708%)
#
# Filtering result:
# reads passed filter: 180214
# reads failed due to low quality: 8062
# reads failed due to too many N: 0
# reads failed due to too short: 47288
# reads with adapter trimmed: 181378
# bases trimmed due to adapters: 2099058
# reads corrected by overlap analysis: 14200
# bases corrected by overlap analysis: 23565
#
# Duplication rate: 33.0357%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 89607
# % of original read pairs: 76.0787%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C52W_fastp.json
# HTML report: ./fastp_out/C52W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C52W.R1.fastq -I 2_demultiplexed/CW3/C52W.R2.fastq -o 3_qc/CW3/C52W.R1.fastq -O 3_qc/CW3/C52W.R2.fastq --unpaired1 3_qc/CW3/C52W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C52W_unpaired.R2.fastq --failed_out 3_qc/CW3/C52W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C52W_merged.fastq -w 6 -h ./fastp_out/C52W_fastp.html -j ./fastp_out/C52W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 149901
# total bases: 22916414
# Q20 bases: 22543324(98.372%)
# Q30 bases: 21797056(95.1155%)
#
# Read2 before filtering:
# total reads: 149901
# total bases: 22933361
# Q20 bases: 22381853(97.5952%)
# Q30 bases: 21390130(93.2708%)
#
# Merged and filtered:
# total reads: 145921
# total bases: 14948079
# Q20 bases: 14810516(99.0797%)
# Q30 bases: 14390852(96.2723%)
#
# Filtering result:
# reads passed filter: 292878
# reads failed due to low quality: 5922
# reads failed due to too many N: 6
# reads failed due to too short: 996
# reads with adapter trimmed: 295566
# bases trimmed due to adapters: 3116667
# reads corrected by overlap analysis: 21903
# bases corrected by overlap analysis: 35618
#
# Duplication rate: 61.6034%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 145921
# % of original read pairs: 97.3449%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C53W_fastp.json
# HTML report: ./fastp_out/C53W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C53W.R1.fastq -I 2_demultiplexed/CW3/C53W.R2.fastq -o 3_qc/CW3/C53W.R1.fastq -O 3_qc/CW3/C53W.R2.fastq --unpaired1 3_qc/CW3/C53W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C53W_unpaired.R2.fastq --failed_out 3_qc/CW3/C53W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C53W_merged.fastq -w 6 -h ./fastp_out/C53W_fastp.html -j ./fastp_out/C53W_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 149364
# total bases: 20952855
# Q20 bases: 20530488(97.9842%)
# Q30 bases: 19793273(94.4658%)
#
# Read2 before filtering:
# total reads: 149364
# total bases: 20943292
# Q20 bases: 20397198(97.3925%)
# Q30 bases: 19468233(92.9569%)
#
# Merged and filtered:
# total reads: 122080
# total bases: 12510811
# Q20 bases: 12397114(99.0912%)
# Q30 bases: 12058762(96.3867%)
#
# Filtering result:
# reads passed filter: 244804
# reads failed due to low quality: 9864
# reads failed due to too many N: 4
# reads failed due to too short: 44056
# reads with adapter trimmed: 246908
# bases trimmed due to adapters: 3141177
# reads corrected by overlap analysis: 19074
# bases corrected by overlap analysis: 31654
#
# Duplication rate: 15.0538%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 122080
# % of original read pairs: 81.7332%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C54W_fastp.json
# HTML report: ./fastp_out/C54W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C54W.R1.fastq -I 2_demultiplexed/CW3/C54W.R2.fastq -o 3_qc/CW3/C54W.R1.fastq -O 3_qc/CW3/C54W.R2.fastq --unpaired1 3_qc/CW3/C54W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C54W_unpaired.R2.fastq --failed_out 3_qc/CW3/C54W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C54W_merged.fastq -w 6 -h ./fastp_out/C54W_fastp.html -j ./fastp_out/C54W_fastp.json
# fastp v0.20.0, time used: 2 seconds
# Read1 before filtering:
# total reads: 139013
# total bases: 21207456
# Q20 bases: 20852944(98.3284%)
# Q30 bases: 20163649(95.0781%)
#
# Read2 before filtering:
# total reads: 139013
# total bases: 21199591
# Q20 bases: 20702015(97.6529%)
# Q30 bases: 19804396(93.4188%)
#
# Merged and filtered:
# total reads: 134573
# total bases: 13796496
# Q20 bases: 13671167(99.0916%)
# Q30 bases: 13292913(96.3499%)
#
# Filtering result:
# reads passed filter: 270070
# reads failed due to low quality: 5838
# reads failed due to too many N: 0
# reads failed due to too short: 2118
# reads with adapter trimmed: 272524
# bases trimmed due to adapters: 2869034
# reads corrected by overlap analysis: 20139
# bases corrected by overlap analysis: 32605
#
# Duplication rate: 58.2996%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 134573
# % of original read pairs: 96.8061%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/C55W_fastp.json
# HTML report: ./fastp_out/C55W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/C55W.R1.fastq -I 2_demultiplexed/CW3/C55W.R2.fastq -o 3_qc/CW3/C55W.R1.fastq -O 3_qc/CW3/C55W.R2.fastq --unpaired1 3_qc/CW3/C55W_unpaired.R1.fastq --unpaired2 3_qc/CW3/C55W_unpaired.R2.fastq --failed_out 3_qc/CW3/C55W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/C55W_merged.fastq -w 6 -h ./fastp_out/C55W_fastp.html -j ./fastp_out/C55W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 29374
# total bases: 3796249
# Q20 bases: 3726692(98.1677%)
# Q30 bases: 3604263(94.9427%)
#
# Read2 before filtering:
# total reads: 29374
# total bases: 3785179
# Q20 bases: 3672166(97.0143%)
# Q30 bases: 3484009(92.0434%)
#
# Merged and filtered:
# total reads: 22022
# total bases: 2268140
# Q20 bases: 2250795(99.2353%)
# Q30 bases: 2196142(96.8257%)
#
# Filtering result:
# reads passed filter: 44120
# reads failed due to low quality: 2388
# reads failed due to too many N: 0
# reads failed due to too short: 12240
# reads with adapter trimmed: 44326
# bases trimmed due to adapters: 512519
# reads corrected by overlap analysis: 3992
# bases corrected by overlap analysis: 6779
#
# Duplication rate: 48.3051%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 22022
# % of original read pairs: 74.9711%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/CF1W_fastp.json
# HTML report: ./fastp_out/CF1W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/CF1W.R1.fastq -I 2_demultiplexed/CW3/CF1W.R2.fastq -o 3_qc/CW3/CF1W.R1.fastq -O 3_qc/CW3/CF1W.R2.fastq --unpaired1 3_qc/CW3/CF1W_unpaired.R1.fastq --unpaired2 3_qc/CW3/CF1W_unpaired.R2.fastq --failed_out 3_qc/CW3/CF1W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/CF1W_merged.fastq -w 6 -h ./fastp_out/CF1W_fastp.html -j ./fastp_out/CF1W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 7613
# total bases: 891596
# Q20 bases: 876598(98.3178%)
# Q30 bases: 848261(95.1396%)
#
# Read2 before filtering:
# total reads: 7613
# total bases: 889445
# Q20 bases: 866809(97.455%)
# Q30 bases: 828076(93.1003%)
#
# Merged and filtered:
# total reads: 4883
# total bases: 502767
# Q20 bases: 499044(99.2595%)
# Q30 bases: 487283(96.9202%)
#
# Filtering result:
# reads passed filter: 9784
# reads failed due to low quality: 526
# reads failed due to too many N: 0
# reads failed due to too short: 4916
# reads with adapter trimmed: 9794
# bases trimmed due to adapters: 111981
# reads corrected by overlap analysis: 734
# bases corrected by overlap analysis: 1146
#
# Duplication rate: 9.09091%
#
# Insert size peak (evaluated by paired-end reads): 143
#
# Read pairs merged: 4883
# % of original read pairs: 64.1403%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/CN3W_fastp.json
# HTML report: ./fastp_out/CN3W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/CN3W.R1.fastq -I 2_demultiplexed/CW3/CN3W.R2.fastq -o 3_qc/CW3/CN3W.R1.fastq -O 3_qc/CW3/CN3W.R2.fastq --unpaired1 3_qc/CW3/CN3W_unpaired.R1.fastq --unpaired2 3_qc/CW3/CN3W_unpaired.R2.fastq --failed_out 3_qc/CW3/CN3W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/CN3W_merged.fastq -w 6 -h ./fastp_out/CN3W_fastp.html -j ./fastp_out/CN3W_fastp.json
# fastp v0.20.0, time used: 1 seconds
# Read1 before filtering:
# total reads: 250717
# total bases: 38763019
# Q20 bases: 38198210(98.5429%)
# Q30 bases: 37000704(95.4536%)
#
# Read2 before filtering:
# total reads: 250717
# total bases: 38908932
# Q20 bases: 37837482(97.2463%)
# Q30 bases: 35930193(92.3443%)
#
# Merged and filtered:
# total reads: 246464
# total bases: 25136055
# Q20 bases: 24910894(99.1042%)
# Q30 bases: 24225655(96.3781%)
#
# Filtering result:
# reads passed filter: 493770
# reads failed due to low quality: 7626
# reads failed due to too many N: 6
# reads failed due to too short: 32
# reads with adapter trimmed: 496790
# bases trimmed due to adapters: 6277416
# reads corrected by overlap analysis: 46484
# bases corrected by overlap analysis: 75673
#
# Duplication rate: 84.225%
#
# Insert size peak (evaluated by paired-end reads): 142
#
# Read pairs merged: 246464
# % of original read pairs: 98.3037%
# % in reads after filtering: 100%
#
#
# JSON report: ./fastp_out/CP3W_fastp.json
# HTML report: ./fastp_out/CP3W_fastp.html
#
# fastp -i 2_demultiplexed/CW3/CP3W.R1.fastq -I 2_demultiplexed/CW3/CP3W.R2.fastq -o 3_qc/CW3/CP3W.R1.fastq -O 3_qc/CW3/CP3W.R2.fastq --unpaired1 3_qc/CW3/CP3W_unpaired.R1.fastq --unpaired2 3_qc/CW3/CP3W_unpaired.R2.fastq --failed_out 3_qc/CW3/CP3W_failed.fastq -q 30 --cut_tail --trim_front1 20 --trim_front2 20 --max_len1 106 --max_len2 106 -l 90 --merge --overlap_len_require 90 --correction --merged_out 4_merged_fastq/CW3/CP3W_merged.fastq -w 6 -h ./fastp_out/CP3W_fastp.html -j ./fastp_out/CP3W_fastp.json
# fastp v0.20.0, time used: 2 seconds

# %% [markdown]
# # derep - denoise - chimera - rerep

# %%
# %%bash
#
# #DEREPLICATE, DENOISE, CHIMERA DETECTION AND REREPLICATE
#
# mkdir 6_denoise_uc/
# mkdir 6_denoise_uc/derep/
# mkdir 6_denoise_uc/denoise/
# mkdir 6_denoise_uc/uchime/
# mkdir 6_denoise_uc/rerep/
# mkdir 6_denoise_uc/clusters/
#
# libraries=$(ls -1 5_merged_fasta/)
# for library in $libraries
# do
#     mkdir 6_denoise_uc/derep/${library}/
#     mkdir 6_denoise_uc/denoise/${library}/
#     mkdir 6_denoise_uc/uchime/${library}/
#     mkdir 6_denoise_uc/rerep/${library}/
#     mkdir 6_denoise_uc/clusters/${library}/
#
#     files=$(ls -1 5_merged_fasta/${library} | grep _merged.fasta | sed 's/_merged.fasta*//')
#     for sample in $files
#     do
#
#         vsearch --derep_fulllength 5_merged_fasta/${library}/${sample}_merged.fasta \
#         --sizeout \
#         --output 6_denoise_uc/derep/${library}/${sample}_derep.fasta --minuniquesize 3 \
#         --uc 6_denoise_uc/clusters/${library}/${sample}_derep.txt
#
#         vsearch --cluster_unoise 6_denoise_uc/derep/${library}/${sample}_derep.fasta \
#         --sizein --sizeout --minsize 1 --unoise_alpha 2.0 \
#         --id 0.99 \
#         --centroids 6_denoise_uc/denoise/${library}/${sample}_denoise.fasta \
#         --uc 6_denoise_uc/clusters/${library}/${sample}_denoise.txt
#
#         vsearch --uchime_ref 6_denoise_uc/denoise/${library}/${sample}_denoise.fasta --db blast_db/12s_full.fasta \
#         --chimeras 6_denoise_uc/uchime/${library}/${sample}_chimera.fasta \
#         --borderline 6_denoise_uc/uchime/${library}/${sample}_chimera.fasta \
#         --mindiffs 1 --mindiv 0.8 --nonchimeras 6_denoise_uc/uchime/${library}/${sample}_nc.fasta \
#
#         vsearch --rereplicate 6_denoise_uc/uchime/${library}/${sample}_nc.fasta \
#         --output 6_denoise_uc/rerep/${library}/${sample}_rerep.fasta #--uc stuff.txt
#
#     done
# done
# Out:
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL01_merged.fasta 100%
# 13272433 nt in 128542 seqs, min 90, max 121, avg 103
# Sorting 100%
# 4993 unique sequences, avg cluster 25.7, median 1, max 38228
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 1060 uniques written, 3933 clusters discarded (78.8%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL01_derep.fasta 100%
# 109929 nt in 1060 seqs, min 91, max 120, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 182 Size min 3, max 46204, avg 5.8
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 14 (7.7%) chimeras, 168 (92.3%) non-chimeras,
# and 0 (0.0%) borderline sequences in 182 unique sequences.
# Taking abundance information into account, this corresponds to
# 201 (0.2%) chimeras, 123945 (99.8%) non-chimeras,
# and 0 (0.0%) borderline sequences in 124146 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 123945 reads from 168 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL02_merged.fasta 100%
# 6913639 nt in 67159 seqs, min 90, max 121, avg 103
# Sorting 100%
# 2486 unique sequences, avg cluster 27.0, median 1, max 25440
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 567 uniques written, 1919 clusters discarded (77.2%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL02_derep.fasta 100%
# 58661 nt in 567 seqs, min 91, max 121, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 149 Size min 3, max 28437, avg 3.8
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 8 (5.4%) chimeras, 141 (94.6%) non-chimeras,
# and 0 (0.0%) borderline sequences in 149 unique sequences.
# Taking abundance information into account, this corresponds to
# 471 (0.7%) chimeras, 64492 (99.3%) non-chimeras,
# and 0 (0.0%) borderline sequences in 64963 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 64492 reads from 141 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL03_merged.fasta 100%
# 9697552 nt in 94159 seqs, min 90, max 121, avg 103
# Sorting 100%
# 3896 unique sequences, avg cluster 24.2, median 1, max 33460
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 866 uniques written, 3030 clusters discarded (77.8%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL03_derep.fasta 100%
# 89930 nt in 866 seqs, min 91, max 121, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 357 Size min 3, max 37549, avg 2.4
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 7 (2.0%) chimeras, 350 (98.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 357 unique sequences.
# Taking abundance information into account, this corresponds to
# 636 (0.7%) chimeras, 90062 (99.3%) non-chimeras,
# and 0 (0.0%) borderline sequences in 90698 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 90062 reads from 350 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL04_merged.fasta 100%
# 6806951 nt in 66339 seqs, min 91, max 121, avg 103
# Sorting 100%
# 2813 unique sequences, avg cluster 23.6, median 1, max 21106
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 573 uniques written, 2240 clusters discarded (79.6%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL04_derep.fasta 100%
# 59185 nt in 573 seqs, min 91, max 121, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 194 Size min 3, max 24458, avg 3.0
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 5 (2.6%) chimeras, 189 (97.4%) non-chimeras,
# and 0 (0.0%) borderline sequences in 194 unique sequences.
# Taking abundance information into account, this corresponds to
# 370 (0.6%) chimeras, 63355 (99.4%) non-chimeras,
# and 0 (0.0%) borderline sequences in 63725 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 63355 reads from 189 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL05_merged.fasta 100%
# 11510683 nt in 112073 seqs, min 90, max 121, avg 103
# Sorting 100%
# 3428 unique sequences, avg cluster 32.7, median 1, max 40971
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 768 uniques written, 2660 clusters discarded (77.6%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL05_derep.fasta 100%
# 79424 nt in 768 seqs, min 91, max 120, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 209 Size min 3, max 45848, avg 3.7
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 8 (3.8%) chimeras, 201 (96.2%) non-chimeras,
# and 0 (0.0%) borderline sequences in 209 unique sequences.
# Taking abundance information into account, this corresponds to
# 784 (0.7%) chimeras, 108311 (99.3%) non-chimeras,
# and 0 (0.0%) borderline sequences in 109095 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 108311 reads from 201 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL06_merged.fasta 100%
# 10956681 nt in 106565 seqs, min 90, max 121, avg 103
# Sorting 100%
# 3482 unique sequences, avg cluster 30.6, median 1, max 36506
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 782 uniques written, 2700 clusters discarded (77.5%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL06_derep.fasta 100%
# 80889 nt in 782 seqs, min 91, max 121, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 249 Size min 3, max 40696, avg 3.1
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 6 (2.4%) chimeras, 243 (97.6%) non-chimeras,
# and 0 (0.0%) borderline sequences in 249 unique sequences.
# Taking abundance information into account, this corresponds to
# 595 (0.6%) chimeras, 102893 (99.4%) non-chimeras,
# and 0 (0.0%) borderline sequences in 103488 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 102893 reads from 243 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL07_merged.fasta 100%
# 8795039 nt in 85709 seqs, min 90, max 121, avg 103
# Sorting 100%
# 2859 unique sequences, avg cluster 30.0, median 1, max 24789
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 626 uniques written, 2233 clusters discarded (78.1%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL07_derep.fasta 100%
# 64726 nt in 626 seqs, min 91, max 121, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 147 Size min 3, max 27816, avg 4.3
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 1 (0.7%) chimeras, 146 (99.3%) non-chimeras,
# and 0 (0.0%) borderline sequences in 147 unique sequences.
# Taking abundance information into account, this corresponds to
# 3 (0.0%) chimeras, 83133 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 83136 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 83133 reads from 146 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL08_merged.fasta 100%
# 7551246 nt in 73203 seqs, min 90, max 120, avg 103
# Sorting 100%
# 2841 unique sequences, avg cluster 25.8, median 1, max 21036
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 563 uniques written, 2278 clusters discarded (80.2%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL08_derep.fasta 100%
# 58472 nt in 563 seqs, min 92, max 120, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 185 Size min 3, max 23645, avg 3.0
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 0 (0.0%) chimeras, 185 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 185 unique sequences.
# Taking abundance information into account, this corresponds to
# 0 (0.0%) chimeras, 70595 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 70595 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 70595 reads from 185 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL09_merged.fasta 100%
# 6124577 nt in 59351 seqs, min 91, max 121, avg 103
# Sorting 100%
# 2492 unique sequences, avg cluster 23.8, median 1, max 20220
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 461 uniques written, 2031 clusters discarded (81.5%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL09_derep.fasta 100%
# 48022 nt in 461 seqs, min 91, max 121, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 191 Size min 3, max 22383, avg 2.4
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 0 (0.0%) chimeras, 191 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 191 unique sequences.
# Taking abundance information into account, this corresponds to
# 0 (0.0%) chimeras, 57045 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 57045 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 57045 reads from 191 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL10_merged.fasta 100%
# 5551555 nt in 53512 seqs, min 90, max 121, avg 104
# Sorting 100%
# 2885 unique sequences, avg cluster 18.5, median 1, max 16554
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 548 uniques written, 2337 clusters discarded (81.0%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL10_derep.fasta 100%
# 57257 nt in 548 seqs, min 90, max 121, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 253 Size min 3, max 18889, avg 2.2
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 1 (0.4%) chimeras, 252 (99.6%) non-chimeras,
# and 0 (0.0%) borderline sequences in 253 unique sequences.
# Taking abundance information into account, this corresponds to
# 83 (0.2%) chimeras, 50746 (99.8%) non-chimeras,
# and 0 (0.0%) borderline sequences in 50829 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 50746 reads from 252 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL11_merged.fasta 100%
# 8678632 nt in 84461 seqs, min 91, max 121, avg 103
# Sorting 100%
# 3169 unique sequences, avg cluster 26.7, median 1, max 19086
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 552 uniques written, 2617 clusters discarded (82.6%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL11_derep.fasta 100%
# 56997 nt in 552 seqs, min 91, max 120, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 135 Size min 3, max 20075, avg 4.1
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 1 (0.7%) chimeras, 134 (99.3%) non-chimeras,
# and 0 (0.0%) borderline sequences in 135 unique sequences.
# Taking abundance information into account, this corresponds to
# 4 (0.0%) chimeras, 81422 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 81426 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 81422 reads from 134 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL12_merged.fasta 100%
# 5499897 nt in 53577 seqs, min 90, max 121, avg 103
# Sorting 100%
# 2056 unique sequences, avg cluster 26.1, median 1, max 16132
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 447 uniques written, 1609 clusters discarded (78.3%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL12_derep.fasta 100%
# 46129 nt in 447 seqs, min 91, max 121, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 117 Size min 3, max 18264, avg 3.8
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 6 (5.1%) chimeras, 111 (94.9%) non-chimeras,
# and 0 (0.0%) borderline sequences in 117 unique sequences.
# Taking abundance information into account, this corresponds to
# 398 (0.8%) chimeras, 51331 (99.2%) non-chimeras,
# and 0 (0.0%) borderline sequences in 51729 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 51331 reads from 111 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL13_merged.fasta 100%
# 4833646 nt in 46929 seqs, min 91, max 121, avg 103
# Sorting 100%
# 1977 unique sequences, avg cluster 23.7, median 1, max 17445
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 457 uniques written, 1520 clusters discarded (76.9%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL13_derep.fasta 100%
# 47315 nt in 457 seqs, min 92, max 121, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 151 Size min 3, max 18352, avg 3.0
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 16 (10.6%) chimeras, 135 (89.4%) non-chimeras,
# and 0 (0.0%) borderline sequences in 151 unique sequences.
# Taking abundance information into account, this corresponds to
# 571 (1.3%) chimeras, 44603 (98.7%) non-chimeras,
# and 0 (0.0%) borderline sequences in 45174 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 44603 reads from 135 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL14_merged.fasta 100%
# 1137529 nt in 11020 seqs, min 92, max 119, avg 103
# Sorting 100%
# 919 unique sequences, avg cluster 12.0, median 1, max 3672
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 132 uniques written, 787 clusters discarded (85.6%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL14_derep.fasta 100%
# 13771 nt in 132 seqs, min 92, max 119, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 93 Size min 3, max 3925, avg 1.4
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 3 (3.2%) chimeras, 90 (96.8%) non-chimeras,
# and 0 (0.0%) borderline sequences in 93 unique sequences.
# Taking abundance information into account, this corresponds to
# 41 (0.4%) chimeras, 10093 (99.6%) non-chimeras,
# and 0 (0.0%) borderline sequences in 10134 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 10093 reads from 90 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL15_merged.fasta 100%
# 5669486 nt in 55227 seqs, min 90, max 119, avg 103
# Sorting 100%
# 2348 unique sequences, avg cluster 23.5, median 1, max 13042
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 486 uniques written, 1862 clusters discarded (79.3%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL15_derep.fasta 100%
# 50175 nt in 486 seqs, min 91, max 119, avg 103
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 130 Size min 3, max 14550, avg 3.7
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 6 (4.6%) chimeras, 124 (95.4%) non-chimeras,
# and 0 (0.0%) borderline sequences in 130 unique sequences.
# Taking abundance information into account, this corresponds to
# 323 (0.6%) chimeras, 52713 (99.4%) non-chimeras,
# and 0 (0.0%) borderline sequences in 53036 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 52713 reads from 124 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL16_merged.fasta 100%
# 5291572 nt in 51277 seqs, min 90, max 121, avg 103
# Sorting 100%
# 2558 unique sequences, avg cluster 20.0, median 1, max 17148
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 518 uniques written, 2040 clusters discarded (79.7%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL16_derep.fasta 100%
# 54086 nt in 518 seqs, min 91, max 121, avg 104
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 266 Size min 3, max 18648, avg 1.9
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 1 (0.4%) chimeras, 265 (99.6%) non-chimeras,
# and 0 (0.0%) borderline sequences in 266 unique sequences.
# Taking abundance information into account, this corresponds to
# 148 (0.3%) chimeras, 48820 (99.7%) non-chimeras,
# and 0 (0.0%) borderline sequences in 48968 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 48820 reads from 265 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL17_merged.fasta 100%
# 1565810 nt in 15125 seqs, min 91, max 121, avg 104
# Sorting 100%
# 1074 unique sequences, avg cluster 14.1, median 1, max 4334
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 140 uniques written, 934 clusters discarded (87.0%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL17_derep.fasta 100%
# 14640 nt in 140 seqs, min 92, max 121, avg 105
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 78 Size min 3, max 4522, avg 1.8
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 1 (1.3%) chimeras, 77 (98.7%) non-chimeras,
# and 0 (0.0%) borderline sequences in 78 unique sequences.
# Taking abundance information into account, this corresponds to
# 40 (0.3%) chimeras, 14013 (99.7%) non-chimeras,
# and 0 (0.0%) borderline sequences in 14053 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 14013 reads from 77 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL-EB_merged.fasta 100%
# 212 nt in 2 seqs, min 106, max 106, avg 106
# Sorting 100%
# 2 unique sequences, avg cluster 1.0, median 1, max 1
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 0 uniques written, 2 clusters discarded (100.0%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
#
#
# Fatal error: Unable to read from file (6_denoise_uc/derep/EA01/BLEL-EB_derep.fasta)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
#
#
# Fatal error: Unable to read from file (6_denoise_uc/denoise/EA01/BLEL-EB_denoise.fasta)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
#
#
# Fatal error: Unable to read from file (6_denoise_uc/uchime/EA01/BLEL-EB_nc.fasta)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL-FB_merged.fasta 100%
# 5395 nt in 48 seqs, min 105, max 117, avg 112
# Sorting 100%
# 36 unique sequences, avg cluster 1.3, median 1, max 3
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 3 uniques written, 33 clusters discarded (91.7%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL-FB_derep.fasta 100%
# 351 nt in 3 seqs, min 117, max 117, avg 117
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 3 Size min 3, max 3, avg 1.0
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 0 (0.0%) chimeras, 3 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 3 unique sequences.
# Taking abundance information into account, this corresponds to
# 0 (0.0%) chimeras, 9 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 9 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 9 reads from 3 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL-Neg_merged.fasta 100%
# 13084 nt in 127 seqs, min 90, max 106, avg 103
# Sorting 100%
# 81 unique sequences, avg cluster 1.6, median 1, max 45
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 2 uniques written, 79 clusters discarded (97.5%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL-Neg_derep.fasta 100%
# 205 nt in 2 seqs, min 102, max 103, avg 102
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 1 Size min 48, max 48, avg 2.0
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 0 (0.0%) chimeras, 1 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 1 unique sequences.
# Taking abundance information into account, this corresponds to
# 0 (0.0%) chimeras, 48 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 48 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 48 reads from 1 amplicons
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Dereplicating file 5_merged_fasta/EA01/BLEL-Pos_merged.fasta 100%
# 1368857 nt in 13424 seqs, min 99, max 106, avg 102
# Sorting 100%
# 344 unique sequences, avg cluster 39.0, median 1, max 12050
# Writing output file 100%
# Writing uc file, first part 100%
# Writing uc file, second part 100%
# 103 uniques written, 241 clusters discarded (70.1%)
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file 6_denoise_uc/derep/EA01/BLEL-Pos_derep.fasta 100%
# 10503 nt in 103 seqs, min 100, max 106, avg 102
# Masking 100%
# Sorting by abundance 100%
# Counting k-mers 100%
# Clustering 100%
# Sorting clusters 100%
# Writing clusters 100%
# Clusters: 1 Size min 13139, max 13139, avg 103.0
# Singletons: 0, 0.0% of seqs, 0.0% of clusters
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Reading file blast_db/12s_full.fasta 100%
# 3656075 nt in 2259 seqs, min 63, max 18999, avg 1618
# Masking 100%
# Counting k-mers 100%
# Creating k-mer index 100%
# Detecting chimeras 100%
# Found 0 (0.0%) chimeras, 1 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 1 unique sequences.
# Taking abundance information into account, this corresponds to
# 0 (0.0%) chimeras, 13139 (100.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 13139 total sequences.
# vsearch v2.14.2_linux_x86_64, 31.3GB RAM, 12 cores
# https://github.com/torognes/vsearch
#
# Rereplicating 100%
# Rereplicated 13139 reads from 1 amplicons

# %% [markdown]
# # Blast

# %%
# %%bash
#
# mkdir blast_out
#
# libraries=$(ls -1 6_denoise_uc/uchime/)
# for library in $libraries
# do
#     mkdir blast_out/${library}/
#     files=$(ls -1 6_denoise_uc/uchime/${library} | grep _nc.fasta | sed 's/_nc.fasta*//')
#     for sample in $files
#     do
#         blastn -query 6_denoise_uc/uchime/${library}/${sample}_nc.fasta \
#         -db blast_db/12s_full \
#         -out blast_out/${library}/${sample}_blast.tsv \
#         -perc_identity 98 \
#         -outfmt '6 qseqid stitle sacc staxids pident qcovs evalue bitscore' \
#         -num_alignments 20 \
#         -num_threads 6
#     done
# done
# Out:
# Warning: [blastn] Query is Empty!

# %% [markdown]
# # Taxonomy to Blast

# %%
# %%bash
#
# mkdir blast_tax
#
# python tax_to_blast.py -i blast_out -o blast_tax -lin new_taxdump/rankedlineage.dmp

# %% [markdown]
# # LCA

# %%
# %%bash
#
# mkdir blast_lca
#
# libraries=$(ls -1 blast_tax/)
# for library in $libraries
# do
#     mkdir blast_lca/${library}/
#     files=$(ls -1 blast_tax/${library} | grep _tax.tsv | sed 's/_tax.tsv*//')
#     for sample in $files
#     do
#         python mlca.py -i blast_tax/${library}/${sample}_tax.tsv -o blast_lca/${library}/${sample}_lca.tsv \
#         -b 10 -id 100 -cov 60 -m 100 -hits 1
#     done
# done

# %% [markdown]
# # LCA to TSV

# %%
# !python mlca-tsv.py -i blast_lca/ -r 6_denoise_uc/rerep/  -o final_out.tsv
